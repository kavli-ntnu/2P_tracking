# %% [markdown]
# # Run some tracking tests

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(style='white')
# %config InlineBackend.figure_format = 'retina'

# %%
pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-2e425d9f1eb5> in <module>()
# ----> 1 pd.read_csv()
#
# TypeError: parser_f() missing 1 required positional argument: 'filepath_or_buffer'

# %%
fname = r"C:\CODE\2P_tracking\pylon_example\tracker_horst_optimized_no_events\Pylon_with_OpenCV\export_bin\bin\image_1.bin"
fname = "/".join(fname.split("\\"))

# %%
loaded_image = np.fromfile(fname, dtype=np.uint8)

# %%
loaded_image.shape
# Out:
# (6750016,)

# %%
loaded_image
# Out:
# array([220,   5,   0, ...,  46,  67,  20], dtype=uint8)

# %%
plt.imshow(loaded_image[:-16].reshape((1500, 1500, 3)));
plt.show()

# %%
# %%time
for i in range(4187): # 85 seconds
    fname = r"C:\CODE\2P_tracking\pylon_example\tracker_horst_optimized_no_events\Pylon_with_OpenCV\export_bin\bin\image_" + str(i+1) + ".bin"
    fname = "/".join(fname.split("\\"))
    loaded_image = np.fromfile(fname, dtype=np.uint8)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/CODE/2P_tracking/pylon_example/tracker_horst_optimized_no_events/Pylon_with_OpenCV/export_bin/bin/image_1.bin'

# %% [markdown]
# # Have a look at the output csv

# %%
csv_fname = r"C:\CODE\2P_tracking\pylon_example\tracker_horst_optimized_no_events\x64\Release\export_timestamps.csv"
csv_fname = "/".join(csv_fname.split("\\"))

# %%
tracking = pd.read_csv(csv_fname,header = 3)

# %%
tracking.head(2)
# Out:
#    frame  cam_timestamp    sys_timestamp   green_x  green_y  red_x  red_y
# 0      1    26612295930  720771151733754   302.294  209.882  316.0  175.5
# 1      2    26632304658  720771343181610   302.375  210.250  316.0  175.5

# %%
len(tracking)
# Out:
# 10905

# %%
tracking["difference"] = np.append(0,np.diff(tracking.cam_timestamp))
tracking["difference_sys"] = np.append(0,np.diff(tracking.sys_timestamp))

# %%
tracking["difference_sec"] = tracking["difference"]/1000000000
tracking["difference_sys_sec"] = tracking["difference_sys"]/1000000000

# %%
tracking.head()
# Out:
#    frame  cam_timestamp    sys_timestamp   green_x  green_y    red_x    red_y  \
# 0      1    26612295930  720771151733754   302.294  209.882  316.000  175.500
# 1      2    26632304658  720771343181610   302.375  210.250  316.000  175.500
# 2      3    26652313629  720771358796238   302.375  210.250  316.333  175.667
# 3      4    26672324463  720771373624972   302.429  210.500  316.500  176.000
# 4      5    26692337565  720771389347959   302.385  210.385  316.333  176.333
#
#    difference  difference_sys  difference_sec  difference_sys_sec
# 0           0               0        0.000000            0.000000
# 1    20008728       191447856        0.020009            0.191448
# 2    20008971        15614628        0.020009            0.015615
# 3    20010834        14828734        0.020011            0.014829
# 4    20013102        15722987        0.020013            0.015723

# %%
figure = plt.figure(figsize=(15,4))
ax = figure.add_subplot(111)
ax.plot(tracking.difference_sec,lw=1,label="difference_sec")
ax.plot(tracking.difference_sys_sec,lw=1,label="difference_sys_sec",alpha=.3)
#ax.axhline(y=0.025,lw=1,color='r')
#ax.set_xlim(0,240)
ax.set_ylim(0.01,0.035)
ax.set_ylabel("Frame time difference [seconds]")
ax.set_xlabel("Frame no.")
plt.legend()
plt.show();

# %%
tracking.describe()
# Out:
#               frame  cam_timestamp  sys_timestamp       green_x       green_y  \
# count  10905.000000   1.090500e+04   1.090500e+04  10905.000000  10905.000000
# mean    5453.000000   1.357112e+11   7.208803e+14    249.449335    272.874236
# std     3148.146677   6.299699e+10   6.299513e+10    137.915190    128.828689
# min        1.000000   2.661230e+10   7.207712e+14      0.000000      0.000000
# 25%     2727.000000   8.116168e+10   7.208257e+14    129.000000    182.167000
# 50%     5453.000000   1.357111e+11   7.208802e+14    274.294000    270.364000
# 75%     8179.000000   1.902607e+11   7.209348e+14    357.824000    383.250000
# max    10905.000000   2.448102e+11   7.209893e+14    482.143000    499.000000
#
#               red_x         red_y    difference  difference_sys  \
# count  10905.000000  10905.000000  1.090500e+04    1.090500e+04
# mean     250.026646    237.161362  2.000898e+07    2.000869e+07
# std      132.381227    129.771179  1.916325e+05    4.079553e+06
# ...

# %% [markdown]
# # Plot trace

# %%
tracking.columns
# Out:
# Index(['frame', 'cam_timestamp', 'sys_timestamp', ' green_x', 'green_y',
#        'red_x', 'red_y', 'difference', 'difference_sys', 'difference_sec',
#        'difference_sys_sec'],
#       dtype='object')

# %%
sns.set(font_scale=1.3,style="white")
figure = plt.figure(figsize=(10,10))
ax = figure.add_subplot(111)
ax.scatter(tracking[" green_x"],tracking.green_y,c='c',s=10,alpha=.8)
ax.scatter(tracking.red_x,tracking.red_y,c='r',s=10,alpha=.7)
sns.despine(left=True,bottom=True)
plt.show()
